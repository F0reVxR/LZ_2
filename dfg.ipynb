# %%
def sum(a, b):
    return a +b

# %%
sum(1.0, 2.1) #Для строк тоже працуе
# Out:
# 3.1

# %%
def variable_1(a, b):
    return a - b

# %%
variable_1('a', 4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 variable_1('a', 4)
#
# NameError: name 'variable_1' is not defined

# %%
a = 'a' # -> to ascii code
ord(a) # -> to str
# Out:
# 97

# %%
def variable_1(a, b):
    diff = len(a) - len(b)
    result = ''
    if diff == 0:
        for i in range(len(a)):
            result += chr(abs(ord(a[i]) - ord(b[i])))
    return result

# %%
variable_1('bvsfdguegdv@@', 'asdwfdvsdbv!!')
# Out:
# '\x01\x03\x0f\x11\x02\x03\x01\x0e\x03\x02\x00\x1f\x1f'
